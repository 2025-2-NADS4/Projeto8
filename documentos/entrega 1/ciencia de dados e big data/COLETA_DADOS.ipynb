# %% [markdown]
# ### **ENTENDENDO OS DADOS**

# %% [markdown]
# COLETA DE DADOS

# %%
import pandas as pd

# Lendo a tabela CampaignQueue
df1 = pd.read_csv('/content/CampaignQueue_semicolon.csv', sep=';')
# Exibe a tabela CampaignQueue
print("\nFILA DE CAMPANHA:")
display(df1)

# Lendo a tabela Campaign
df2 = pd.read_csv('/content/Campaign_semicolon.csv', sep=';')
# Exibe a tabela Campaign
print("\nCAMPANHAS:")
display(df2)

# Lendo a tabela Customer
df3 = pd.read_csv('/content/Customer_semicolon.csv', sep=';')
# Exibe a tabela Customer
print("\nCLIENTES:")
display(df3)

# Lendo a tabela Order
df4 = pd.read_csv('/content/Order_semicolon.csv', sep=';')

# Exibe a tabela Order
print("\nPEDIDOS:")
display(df4)
